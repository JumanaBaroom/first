# %%
import sys
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from numpy.random import seed
from tensorflow import set_random_seed
import scipy as sp
import scipy.io as spio
from matplotlib import pyplot as plt
import matplotlib.pylab as pl
# %matplotlib inline
from tensorflow.python import keras
from sklearn.model_selection import train_test_split ,KFold
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.layers import Dense, Flatten, Conv1D, Dropout, MaxPooling1D, Reshape, GlobalAveragePooling1D
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.layers import LeakyReLU
from sklearn.metrics import classification_report

from numpy import mean
from numpy import std
import pandas as pd
from scipy import stats
from scipy.stats import zscore
from scipy import stats
from sklearn import metrics
import keras.backend as k
import seaborn as sns
from sklearn import preprocessing
from numpy import mean
from numpy import std

from scipy import stats
from scipy.stats import zscore
from keras.constraints import max_norm
from sklearn.preprocessing import MinMaxScaler

dataset = np.loadtxt("datalast.csv",delimiter=",")
print(dataset)

#def feature_normalize(dataset):


   # mu = np.mean(dataset, axis=0)
    #sigma = np.std(dataset, axis=0)
    #z=(dataset - mu)/sigma
    #dataset=stats.zscore(z)
    #return (dataset)

#ature_normalize(dataset)
#print(dataset)


X = dataset[:,0:177]
y = dataset[:,178]

dataset = stats.zscore(dataset)
scaler = MinMaxScaler(feature_range=(-1,1))
dataset = scaler.fit_transform(dataset)
print(dataset)

LABELS = ["0",

          "1",

          "2",

          "3",

          "4"]

 

def show_confusion_matrix(validations, predictions):
 

    #matrix = metrics.confusion_matrix(y_test_hot, predictions)

    plt.figure(figsize=(6, 4))

    sns.heatmap(c,

                cmap="coolwarm",

                linecolor='white',

                linewidths=1,

                xticklabels=LABELS,

                yticklabels=LABELS,

                annot=True,

                fmt="d")

    plt.title("Confusion Matrix")

    plt.ylabel("True Label")

    plt.xlabel("Predicted Label")

    plt.show()
    
def counts_from_confusion(confusion):

    counts_list=[]
    
# Iterate through classes and store the counts

    for i in range(confusion.shape[0]):

        tp = confusion[i, i]
        
        fn_mask = np.zeros(confusion.shape)

        fn_mask[i, :] = 1

        fn_mask[i, i] = 0

        fn = np.sum(np.multiply(confusion, fn_mask))



        fp_mask = np.zeros(confusion.shape)

        fp_mask[:, i] = 1

        fp_mask[i, i] = 0

        fp = np.sum(np.multiply(confusion, fp_mask))
        
        tn_mask = 1 - (fn_mask + fp_mask)

        tn_mask[i, i] = 0

        tn = np.sum(np.multiply(confusion, tn_mask))



        counts_list.append({'Class\n': i,

                           'TP \n' : tp,
   
                           'FN\n': fn,

                           'FP\n': fp,

                           'TN\n': tn})
        Sens= tp / tp + fn
        Spec= tn / tn + fp
        print('sensitivity', Sens)

        print('specificity',Spec )

    return counts_list


model = Sequential()
model.add(Conv1D(60, 10, activation='relu', input_shape=(177,1)))
model.add(Conv1D(60, 10, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.15))
model.add(Conv1D(100, 10, activation='relu'))
model.add(Conv1D(100, 10, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.15))
model.add(Conv1D(50, 5, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.15))
model.add(Dense(5, activation='softmax'))

print("Number of columns in the dataframe: %i" % (X.shape[1]))
print("Number of rows in the dataframe: %i\n" % (X.shape[0]))
print("\n--- Create neural network model ---\n")
print(model.summary())

cvscores = []
j=1
kf=KFold(n_splits=10, random_state=None, shuffle=True)

scores = list()

for train_index, test_index in kf.split(X):
    print('\nFold ',j, "\n")
    print("Train Index: ", train_index.shape, "\n")
    print("Test Index: ", test_index.shape)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
   
 

   
    print("\n--- Reshape data to be accepted by Keras ---\n")
    X_train = np.reshape(X_train,(X_train.shape[0], X_train.shape[1],1))
    y_train = y_train.reshape(y_train.shape[0],1)
    y_train_hot = np_utils.to_categorical(y_train-1, 5) # subtracting y_train-1 as keras starts num_Classes index from 0 and we had it from 1 to 5
    print(X_train.shape)
    print(y_train_hot.shape)
   
  
    
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    print("\n--- Fit the model ---\n")
    history = model.fit(X_train, y_train_hot, batch_size = 400, epochs=80, validation_split=None, verbose=1)
    
    predictions = model.predict(X_train)

    y_train_hot = np.argmax(y_train_hot, axis=-1)

    predictions = np.argmax(predictions, axis=-1)

    c = confusion_matrix(y_train_hot, predictions)

    print('Confusion matrix:\n', c)
    print(counts_from_confusion(c))
    show_confusion_matrix(y_train_hot, predictions)

    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
    y_test = y_test.reshape(y_test.shape[0],1)
    
    y_test_hot = np_utils.to_categorical(y_test-1, 5)
   
    # evaluate the model
    print("\n--- evaluate the model ---\n")
    scores = model.evaluate(X_test, y_test_hot,verbose=1)
    

    
    predictions = model.predict(X_test)

    y_test_hot = np.argmax(y_test_hot, axis=-1)

    predictions = np.argmax(predictions, axis=-1)

    c = confusion_matrix(y_test_hot, predictions)

    print('Confusion matrix:\n', c)
    print(counts_from_confusion(c))
    show_confusion_matrix(y_test_hot, predictions)
    
    
    print(classification_report(y_test_hot, predictions))

    
    print("\n--- Learning curve of model training ---\n")
    plt.figure()
    plt.plot(history.history['acc'], "g--", label="Accuracy of training data")
    #plt.plot(history.history['val_acc'], "g", label="Accuracy of validation data")
    plt.plot(history.history['loss'], "r--", label="Loss of training data")
    #plt.plot(history.history['val_loss'], "r", label="Loss of validation data")
    plt.title('Model Accuracy and Loss')
    plt.legend()
    plt.show()

    cvscores.append(scores[1] * 100)
    j=j+1
print("Avarage accuracy :%.2f% %" , np.mean(cvscores))
print(classification_report(y_test_hot, predictions))
# Out:
# Using TensorFlow backend.
# [[135. 190. 229. ... -83. -51.   4.]
#  [386. 382. 356. ... 143. 129.   1.]
#  [-32. -39. -47. ... -35. -36.   5.]
#  ...
#  [ 14.   6. -13. ...  -1.  -8.   5.]
#  [-40. -25.  -9. ...  59.  55.   3.]
#  [ 29.  41.  57. ...   2.  20.   4.]]
# [[ 0.10743338  0.14221346  0.16874292 ... -0.12877583 -0.05021368
#    0.5       ]
#  [ 0.24824684  0.25035201  0.24065685 ... -0.00900901  0.04594017
#   -1.        ]
#  [ 0.01374474  0.01323571  0.01245753 ... -0.10333863 -0.04220085
#    1.        ]
#  ...
#  [ 0.03955119  0.03858068  0.03171008 ... -0.08532061 -0.02724359
#    1.        ]
#  [ 0.00925666  0.02112081  0.03397508 ... -0.05352411  0.00641026
#    0.        ]
#  [ 0.04796634  0.05829344  0.07134768 ... -0.08373079 -0.01228632
#    0.5       ]]
# Number of columns in the dataframe: 177
# Number of rows in the dataframe: 11500
#
#
# --- Create neural network model ---
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None,
80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.3311 - acc: 0.8490
# Epoch 56/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.3001 - acc: 0.8651
# Epoch 57/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.3196 - acc: 0.8516
# Epoch 58/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.3034 - acc: 0.8635
# Epoch 59/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2883 - acc: 0.8712
# Epoch 60/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.2837 - acc: 0.8683
# Epoch 61/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2814 - acc: 0.8773
# Epoch 62/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2887 - acc: 0.8661
# Epoch 63/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.2846 - acc: 0.8699
# Epoch 64/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2673 - acc: 0.8822
# Epoch 65/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2484 - acc: 0.8895
# Epoch 66/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.2446 - acc: 0.8897
# Epoch 67/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2425 - acc: 0.8943
# Epoch 68/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2507 - acc: 0.8893
# Epoch 69/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2438 - acc: 0.8936
# Epoch 70/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2306 - acc: 0.9003
# Epoch 71/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2504 - acc: 0.8921
# Epoch 72/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2395 - acc: 0.8974
# Epoch 73/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.2234 - acc: 0.9045
# Epoch 74/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2075 - acc: 0.9082
# Epoch 75/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2369 - acc: 0.9002
# Epoch 76/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.2115 - acc: 0.9107
# Epoch 77/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.2087 - acc: 0.9077
# Epoch 78/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.1864 - acc: 0.9214
# Epoch 79/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.1936 - acc: 0.9179
# Epoch 80/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.1912 - acc: 0.9214
# Confusion matrix:
#  [[2068    8    0    0    0]
#  [   1 1909  161    0    0]
#  [   0  106 1975    0    0]
#  [   0    0    0 1888  184]
#  [   0    0    3    5 2042]]
# sensitivity 9.0
# specificity 2.0
# sensitivity 163.0
# specificity 115.0
# sensitivity 107.0
# specificity 165.0
# sensitivity 185.0
# specificity 6.0
# sensitivity 9.0
# specificity 185.0
# [{'Class\n': 0, 'TP \n': 2068, 'FN\n': 8.0, 'FP\n': 1.0, 'TN\n': 8273.0}, {'Class\n': 1, 'TP \n': 1909, 'FN\n': 162.0, 'FP\n': 114.0, 'TN\n': 8165.0}, {'Class\n': 2, 'TP \n': 1975, 'FN\n': 106.0, 'FP\n': 164.0, 'TN\n': 8105.0}, {'Class\n': 3, 'TP \n': 1888, 'FN\n': 184.0, 'FP\n': 5.0, 'TN\n': 8273.0}, {'Class\n': 4, 'TP \n': 2042, 'FN\n': 8.0, 'FP\n': 184.0, 'TN\n': 8116.0}]
# --- evaluate the model ---
#
# 1150/1150 [==============================] - 0s 346us/step
# Confusion matrix:
#  [[219   4   1   0   0]
#  [  3 144  75   0   7]
#  [  1  48 160   0  10]
#  [  0   1   1 187  39]
#  [  0   0   2  11 237]]
# sensitivity 6.0
# specificity 5.0
# sensitivity 86.0
# specificity 54.0
# sensitivity 60.0
# specificity 80.0
# sensitivity 42.0
# specificity 12.0
# sensitivity 14.0
# specificity 57.0
# [{'Class\n': 0, 'TP \n': 219, 'FN\n': 5.0, 'FP\n': 4.0, 'TN\n': 922.0}, {'Class\n': 1, 'TP \n': 144, 'FN\n': 85.0, 'FP\n': 53.0, 'TN\n': 868.0}, {'Class\n': 2, 'TP \n': 160, 'FN\n': 59.0, 'FP\n': 79.0, 'TN\n': 852.0}, {'Class\n': 3, 'TP \n': 187, 'FN\n': 41.0, 'FP\n': 11.0, 'TN\n': 911.0}, {'Class\n': 4, 'TP \n': 237, 'FN\n': 13.0, 'FP\n': 56.0, 'TN\n': 844.0}]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98
80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0570 - acc: 0.9778
# Epoch 48/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0646 - acc: 0.9771
# Epoch 49/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0548 - acc: 0.9791
# Epoch 50/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0600 - acc: 0.9793
# Epoch 51/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0472 - acc: 0.9822
# Epoch 52/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0494 - acc: 0.9820
# Epoch 53/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0430 - acc: 0.9850
# Epoch 54/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0442 - acc: 0.9850
# Epoch 55/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0568 - acc: 0.9792
# Epoch 56/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0666 - acc: 0.9744
# Epoch 57/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0761 - acc: 0.9729
# Epoch 58/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0587 - acc: 0.9790
# Epoch 59/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0523 - acc: 0.9804
# Epoch 60/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0530 - acc: 0.9814
# Epoch 61/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0499 - acc: 0.9823
# Epoch 62/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0423 - acc: 0.9854
# Epoch 63/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0471 - acc: 0.9831
# Epoch 64/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0410 - acc: 0.9867
# Epoch 65/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0479 - acc: 0.9837
# Epoch 66/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0395 - acc: 0.9861
# Epoch 67/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0435 - acc: 0.9846
# Epoch 68/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0373 - acc: 0.9877
# Epoch 69/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0356 - acc: 0.9872
# Epoch 70/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0307 - acc: 0.9886
# Epoch 71/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0450 - acc: 0.9843
# Epoch 72/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0386 - acc: 0.9861
# Epoch 73/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0367 - acc: 0.9878
# Epoch 74/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0441 - acc: 0.9857
# Epoch 75/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0449 - acc: 0.9843
# Epoch 76/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0393 - acc: 0.9868
# Epoch 77/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0362 - acc: 0.9880
# Epoch 78/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0366 - acc: 0.9873
# Epoch 79/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0339 - acc: 0.9885
# Epoch 80/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0333 - acc: 0.9891
# Confusion matrix:
#  [[2062    1    0    0    0]
#  [   0 2067    0    0    0]
#  [   0    2 2073    0    0]
#  [   0    0    0 2080    0]
#  [   0    0    0    0 2065]]
# sensitivity 2.0
# specificity 1.0
# sensitivity 1.0
# specificity 4.0
# sensitivity 3.0
# specificity 1.0
# sensitivity 1.0
# specificity 1.0
# sensitivity 1.0
# specificity 1.0
# [{'Class\n': 0, 'TP \n': 2062, 'FN\n': 1.0, 'FP\n': 0.0, 'TN\n': 8287.0}, {'Class\n': 1, 'TP \n': 2067, 'FN\n': 0.0, 'FP\n': 3.0, 'TN\n': 8280.0}, {'Class\n': 2, 'TP \n': 2073, 'FN\n': 2.0, 'FP\n': 0.0, 'TN\n': 8275.0}, {'Class\n': 3, 'TP \n': 2080, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8270.0}, {'Class\n': 4, 'TP \n': 2065, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8285.0}]
# --- evaluate the model ---
#
# 1150/1150 [==============================] - 0s 131us/step
# Confusion matrix:
#  [[237   0   0   0   0]
#  [  0 199  28   0   6]
#  [  0  43 173   0   9]
#  [  0   0   0 199  21]
#  [  0   0   0  14 221]]
# sensitivity 1.0
# specificity 1.0
# sensitivity 35.0
# specificity 44.0
# sensitivity 53.0
# specificity 29.0
# sensitivity 22.0
# specificity 15.0
# sensitivity 15.0
# specificity 37.0
# [{'Class\n': 0, 'TP \n': 237, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 913.0}, {'Class\n': 1, 'TP \n': 199, 'FN\n': 34.0, 'FP\n': 43.0, 'TN\n': 874.0}, {'Class\n': 2, 'TP \n': 173, 'FN\n': 52.0, 'FP\n': 28.0, 'TN\n': 897.0}, {'Class\n': 3, 'TP \n': 199, 'FN\n': 21.0, 'FP\n': 14.0, 'TN\n': 916.0}, {'Class\n': 4, 'TP \n': 221, 'FN\n': 14.0, 'FP\n': 36.0, 'TN\n': 879.0}]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00
80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0283 - acc: 0.9908
# Epoch 56/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0263 - acc: 0.9900
# Epoch 57/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0207 - acc: 0.9929
# Epoch 58/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0165 - acc: 0.9945
# Epoch 59/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0192 - acc: 0.9941
# Epoch 60/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0308 - acc: 0.9900
# Epoch 61/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0360 - acc: 0.9870
# Epoch 62/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0401 - acc: 0.9861
# Epoch 63/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0314 - acc: 0.9900
# Epoch 64/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0316 - acc: 0.9885
# Epoch 65/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0203 - acc: 0.9931
# Epoch 66/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0257 - acc: 0.9912
# Epoch 67/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0389 - acc: 0.9868
# Epoch 68/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0323 - acc: 0.9904
# Epoch 69/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0316 - acc: 0.9899
# Epoch 70/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0327 - acc: 0.9887
# Epoch 71/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0243 - acc: 0.9910
# Epoch 72/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0372 - acc: 0.9859
# Epoch 73/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0282 - acc: 0.9916
# Epoch 74/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0276 - acc: 0.9913
# Epoch 75/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0206 - acc: 0.9930
# Epoch 76/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0224 - acc: 0.9926
# Epoch 77/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0290 - acc: 0.9904
# Epoch 78/80
# 10350/10350 [==============================] - 1s 92us/step - loss: 0.0296 - acc: 0.9906
# Epoch 79/80
# 10350/10350 [==============================] - 1s 94us/step - loss: 0.0581 - acc: 0.9805
# Epoch 80/80
# 10350/10350 [==============================] - 1s 95us/step - loss: 0.0404 - acc: 0.9867
# Confusion matrix:
#  [[2073    0    0    0    0]
#  [   0 2077    1    0    0]
#  [   0    8 2060    0    0]
#  [   0    0    0 2063    0]
#  [   0    0    0    0 2068]]
# sensitivity 1.0
# specificity 1.0
# sensitivity 2.0
# specificity 9.0
# sensitivity 9.0
# specificity 2.0
# sensitivity 1.0
# specificity 1.0
# sensitivity 1.0
# specificity 1.0
# [{'Class\n': 0, 'TP \n': 2073, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8277.0}, {'Class\n': 1, 'TP \n': 2077, 'FN\n': 1.0, 'FP\n': 8.0, 'TN\n': 8264.0}, {'Class\n': 2, 'TP \n': 2060, 'FN\n': 8.0, 'FP\n': 1.0, 'TN\n': 8281.0}, {'Class\n': 3, 'TP \n': 2063, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8287.0}, {'Class\n': 4, 'TP \n': 2068, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8282.0}]
# --- evaluate the model ---
#
# 1150/1150 [==============================] - 0s 160us/step
# Confusion matrix:
#  [[226   1   0   0   0]
#  [  0 217   4   0   1]
#  [  1  19 211   0   1]
#  [  0   0   0 237   0]
#  [  0   0   0   4 228]]
# sensitivity 2.0
# specificity 2.0
# sensitivity 6.0
# specificity 21.0
# sensitivity 22.0
# specificity 5.0
# sensitivity 1.0
# specificity 5.0
# sensitivity 5.0
# specificity 3.0
# [{'Class\n': 0, 'TP \n': 226, 'FN\n': 1.0, 'FP\n': 1.0, 'TN\n': 922.0}, {'Class\n': 1, 'TP \n': 217, 'FN\n': 5.0, 'FP\n': 20.0, 'TN\n': 908.0}, {'Class\n': 2, 'TP \n': 211, 'FN\n': 21.0, 'FP\n': 4.0, 'TN\n': 914.0}, {'Class\n': 3, 'TP \n': 237, 'FN\n': 0.0, 'FP\n': 4.0, 'TN\n': 909.0}, {'Class\n': 4, 'TP \n': 228, 'FN\n': 4.0, 'FP\n': 2.0, 'TN\n': 916.0}]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00
80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0143 - acc: 0.9956
# Epoch 58/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0185 - acc: 0.9936
# Epoch 59/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0208 - acc: 0.9925
# Epoch 60/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0226 - acc: 0.9928
# Epoch 61/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0205 - acc: 0.9922
# Epoch 62/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0280 - acc: 0.9915
# Epoch 63/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0329 - acc: 0.9887
# Epoch 64/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0199 - acc: 0.9939
# Epoch 65/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0135 - acc: 0.9951
# Epoch 66/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0236 - acc: 0.9915
# Epoch 67/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0229 - acc: 0.9916
# Epoch 68/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0231 - acc: 0.9935
# Epoch 69/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0149 - acc: 0.9951
# Epoch 70/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0179 - acc: 0.9943
# Epoch 71/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0190 - acc: 0.9946
# Epoch 72/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0295 - acc: 0.9900
# Epoch 73/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0322 - acc: 0.9894
# Epoch 74/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0244 - acc: 0.9919
# Epoch 75/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0365 - acc: 0.9894
# Epoch 76/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0310 - acc: 0.9898
# Epoch 77/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0246 - acc: 0.9906
# Epoch 78/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0156 - acc: 0.9941
# Epoch 79/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0198 - acc: 0.9939
# Epoch 80/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0144 - acc: 0.9955
# Confusion matrix:
#  [[2099    0    0    0    0]
#  [   0 2058    1    0    0]
#  [   0    0 2056    0    0]
#  [   0    0    0 2068    0]
#  [   0    0    0    1 2067]]
# sensitivity 1.0
# specificity 1.0
# sensitivity 2.0
# specificity 1.0
# sensitivity 1.0
# specificity 2.0
# sensitivity 1.0
# specificity 2.0
# sensitivity 2.0
# specificity 1.0
# [{'Class\n': 0, 'TP \n': 2099, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8251.0}, {'Class\n': 1, 'TP \n': 2058, 'FN\n': 1.0, 'FP\n': 0.0, 'TN\n': 8291.0}, {'Class\n': 2, 'TP \n': 2056, 'FN\n': 0.0, 'FP\n': 1.0, 'TN\n': 8293.0}, {'Class\n': 3, 'TP \n': 2068, 'FN\n': 0.0, 'FP\n': 1.0, 'TN\n': 8281.0}, {'Class\n': 4, 'TP \n': 2067, 'FN\n': 1.0, 'FP\n': 0.0, 'TN\n': 8282.0}]
# --- evaluate the model ---
#
# 1150/1150 [==============================] - 0s 173us/step
# Confusion matrix:
#  [[199   1   1   0   0]
#  [  0 236   5   0   0]
#  [  0   3 240   0   1]
#  [  0   0   0 229   3]
#  [  0   0   0   2 230]]
# sensitivity 3.0
# specificity 1.0
# sensitivity 6.0
# specificity 5.0
# sensitivity 5.0
# specificity 7.0
# sensitivity 4.0
# specificity 3.0
# sensitivity 3.0
# specificity 5.0
# [{'Class\n': 0, 'TP \n': 199, 'FN\n': 2.0, 'FP\n': 0.0, 'TN\n': 949.0}, {'Class\n': 1, 'TP \n': 236, 'FN\n': 5.0, 'FP\n': 4.0, 'TN\n': 905.0}, {'Class\n': 2, 'TP \n': 240, 'FN\n': 4.0, 'FP\n': 6.0, 'TN\n': 900.0}, {'Class\n': 3, 'TP \n': 229, 'FN\n': 3.0, 'FP\n': 2.0, 'TN\n': 916.0}, {'Class\n': 4, 'TP \n': 230, 'FN\n': 2.0, 'FP\n': 4.0, 'TN\n': 914.0}]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99
80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0146 - acc: 0.9952
# Epoch 61/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0127 - acc: 0.9961
# Epoch 62/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0487 - acc: 0.9871
# Epoch 63/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0380 - acc: 0.9880
# Epoch 64/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0155 - acc: 0.9953
# Epoch 65/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0099 - acc: 0.9971
# Epoch 66/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0103 - acc: 0.9972
# Epoch 67/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0114 - acc: 0.9972
# Epoch 68/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0113 - acc: 0.9963
# Epoch 69/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0263 - acc: 0.9918
# Epoch 70/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0140 - acc: 0.9959
# Epoch 71/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0120 - acc: 0.9957
# Epoch 72/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0068 - acc: 0.9974
# Epoch 73/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0110 - acc: 0.9964
# Epoch 74/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0154 - acc: 0.9952
# Epoch 75/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0111 - acc: 0.9962
# Epoch 76/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0167 - acc: 0.9943
# Epoch 77/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0197 - acc: 0.9941
# Epoch 78/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0117 - acc: 0.9962
# Epoch 79/80
# 10350/10350 [==============================] - 1s 89us/step - loss: 0.0163 - acc: 0.9949
# Epoch 80/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0182 - acc: 0.9935
# Confusion matrix:
#  [[2064    3    0    0    1]
#  [   0 2057    1    0    0]
#  [   0    0 2066    0    0]
#  [   0    0    0 2074    0]
#  [   0    0    0    0 2084]]
# sensitivity 5.0
# specificity 1.0
# sensitivity 2.0
# specificity 4.0
# sensitivity 1.0
# specificity 2.0
# sensitivity 1.0
# specificity 1.0
# sensitivity 1.0
# specificity 2.0
# [{'Class\n': 0, 'TP \n': 2064, 'FN\n': 4.0, 'FP\n': 0.0, 'TN\n': 8282.0}, {'Class\n': 1, 'TP \n': 2057, 'FN\n': 1.0, 'FP\n': 3.0, 'TN\n': 8289.0}, {'Class\n': 2, 'TP \n': 2066, 'FN\n': 0.0, 'FP\n': 1.0, 'TN\n': 8283.0}, {'Class\n': 3, 'TP \n': 2074, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8276.0}, {'Class\n': 4, 'TP \n': 2084, 'FN\n': 0.0, 'FP\n': 1.0, 'TN\n': 8265.0}]
# --- evaluate the model ---
#
# 1150/1150 [==============================] - 0s 312us/step
# Confusion matrix:
#  [[231   1   0   0   0]
#  [  0 241   1   0   0]
#  [  0   3 231   0   0]
#  [  0   0   0 224   2]
#  [  0   0   0   0 216]]
# sensitivity 2.0
# specificity 1.0
# sensitivity 2.0
# specificity 5.0
# sensitivity 4.0
# specificity 2.0
# sensitivity 3.0
# specificity 1.0
# sensitivity 1.0
# specificity 3.0
# [{'Class\n': 0, 'TP \n': 231, 'FN\n': 1.0, 'FP\n': 0.0, 'TN\n': 918.0}, {'Class\n': 1, 'TP \n': 241, 'FN\n': 1.0, 'FP\n': 4.0, 'TN\n': 904.0}, {'Class\n': 2, 'TP \n': 231, 'FN\n': 3.0, 'FP\n': 1.0, 'TN\n': 915.0}, {'Class\n': 3, 'TP \n': 224, 'FN\n': 2.0, 'FP\n': 0.0, 'TN\n': 924.0}, {'Class\n': 4, 'TP \n': 216, 'FN\n': 0.0, 'FP\n': 2.0, 'TN\n': 932.0}]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00
80
# 10350/10350 [==============================] - 1s 91us/step - loss: 0.0084 - acc: 0.9973
# Epoch 63/80
# 10350/10350 [==============================] - 1s 93us/step - loss: 0.0103 - acc: 0.9964
# Epoch 64/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0061 - acc: 0.9981
# Epoch 65/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0074 - acc: 0.9984
# Epoch 66/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0096 - acc: 0.9968
# Epoch 67/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0134 - acc: 0.9967
# Epoch 68/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0233 - acc: 0.9937
# Epoch 69/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0162 - acc: 0.9951
# Epoch 70/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0119 - acc: 0.9955
# Epoch 71/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0122 - acc: 0.9960
# Epoch 72/80
# 10350/10350 [==============================] - 1s 91us/step - loss: 0.0096 - acc: 0.9964
# Epoch 73/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0146 - acc: 0.9968
# Epoch 74/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0110 - acc: 0.9964
# Epoch 75/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0140 - acc: 0.9952
# Epoch 76/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0122 - acc: 0.9960
# Epoch 77/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0098 - acc: 0.9969
# Epoch 78/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0103 - acc: 0.9974
# Epoch 79/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0091 - acc: 0.9963
# Epoch 80/80
# 10350/10350 [==============================] - 1s 90us/step - loss: 0.0120 - acc: 0.9961
# Confusion matrix:
#  [[2055    0    0    0    0]
#  [   0 2076    0    0    0]
#  [   0    1 2092    0    0]
#  [   0    0    0 2060    0]
#  [   0    0    0    0 2066]]
# sensitivity 1.0
# specificity 1.0
# sensitivity 1.0
# specificity 2.0
# sensitivity 2.0
# specificity 1.0
# sensitivity 1.0
# specificity 1.0
# sensitivity 1.0
# specificity 1.0
# [{'Class\n': 0, 'TP \n': 2055, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8295.0}, {'Class\n': 1, 'TP \n': 2076, 'FN\n': 0.0, 'FP\n': 1.0, 'TN\n': 8273.0}, {'Class\n': 2, 'TP \n': 2092, 'FN\n': 1.0, 'FP\n': 0.0, 'TN\n': 8257.0}, {'Class\n': 3, 'TP \n': 2060, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8290.0}, {'Class\n': 4, 'TP \n': 2066, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 8284.0}]
# --- evaluate the model ---
#
# 1150/1150 [==============================] - 0s 337us/step
# Confusion matrix:
#  [[245   0   0   0   0]
#  [  0 224   0   0   0]
#  [  0   3 204   0   0]
#  [  0   0   0 240   0]
#  [  0   0   0   0 234]]
# sensitivity 1.0
# specificity 1.0
# sensitivity 1.0
# specificity 4.0
# sensitivity 4.0
# specificity 1.0
# sensitivity 1.0
# specificity 1.0
# sensitivity 1.0
# specificity 1.0
# [{'Class\n': 0, 'TP \n': 245, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 905.0}, {'Class\n': 1, 'TP \n': 224, 'FN\n': 0.0, 'FP\n': 3.0, 'TN\n': 923.0}, {'Class\n': 2, 'TP \n': 204, 'FN\n': 3.0, 'FP\n': 0.0, 'TN\n': 943.0}, {'Class\n': 3, 'TP \n': 240, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 910.0}, {'Class\n': 4, 'TP \n': 234, 'FN\n': 0.0, 'FP\n': 0.0, 'TN\n': 916.0}]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       245
#            1       0.99      1.00      0.99       224
#            2       1.00      0.99      0.99       207
#            3       1.00      1.00      1.00       240
#            4       1.00      1.00      1.00       234
#
#    micro avg       1.00      1.00      1.00      1150
#    macro avg       1.00      1.00      1.00      1150
# weighted avg       1.00      1.00      1.00      1150
#
#
# --- Learning curve of model training ---
# Avarage accuracy :%.2f% % 96.51304348137069
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       245
#            1       0.99      1.00      0.99       224
#            2       1.00      0.99      0.99       207
#            3       1.00      1.00      1.00       240
#            4       1.00      1.00      1.00       234
#
#    micro avg       1.00      1.00      1.00      1150
#    macro avg       1.00      1.00      1.00      1150
# weighted avg       1.00      1.00      1.00      1150
