# %%
import sys
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from numpy.random import seed
from tensorflow import set_random_seed
import scipy as sp
import scipy.io as spio
from matplotlib import pyplot as plt
import matplotlib.pylab as pl
# %matplotlib inline
from tensorflow.python import keras
from sklearn.model_selection import train_test_split ,KFold
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.layers import Dense, Flatten, Conv1D, Dropout, MaxPooling1D, Reshape, GlobalAveragePooling1D
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.layers import LeakyReLU

from numpy import mean
from numpy import std
import pandas as pd
from scipy import stats
from scipy.stats import zscore
from scipy import stats
from sklearn import metrics
import keras.backend as k
import seaborn as sns
from sklearn import preprocessing
from numpy import mean
from numpy import std

from scipy import stats
from scipy.stats import zscore
from keras.constraints import max_norm


dataset = np.loadtxt("datalast.csv",delimiter=",")

def feature_normalize(dataset):

    mu = np.mean(dataset, axis=0)
    sigma = np.std(dataset, axis=0)
    z=(dataset - mu)/sigma
    dataset=stats.zscore(z)
    return (dataset)

feature_normalize(dataset)

X = dataset[:,0:177]
y = dataset[:,178]



LABELS = ["0",

          "1",

          "2",

          "3",

          "4"]

 

def show_confusion_matrix(validations, predictions):
 

    #matrix = metrics.confusion_matrix(y_test_hot, predictions)

    plt.figure(figsize=(6, 4))

    sns.heatmap(c,

                cmap="coolwarm",

                linecolor='white',

                linewidths=1,

                xticklabels=LABELS,

                yticklabels=LABELS,

                annot=True,

                fmt="d")

    plt.title("Confusion Matrix")

    plt.ylabel("True Label")

    plt.xlabel("Predicted Label")

    plt.show()
    
def counts_from_confusion(confusion):

    counts_list=[]
    
# Iterate through classes and store the counts

    for i in range(confusion.shape[0]):

        tp = confusion[i, i]
        
        fn_mask = np.zeros(confusion.shape)

        fn_mask[i, :] = 1

        fn_mask[i, i] = 0

        fn = np.sum(np.multiply(confusion, fn_mask))



        fp_mask = np.zeros(confusion.shape)

        fp_mask[:, i] = 1

        fp_mask[i, i] = 0

        fp = np.sum(np.multiply(confusion, fp_mask))
        
        tn_mask = 1 - (fn_mask + fp_mask)

        tn_mask[i, i] = 0

        tn = np.sum(np.multiply(confusion, tn_mask))



        counts_list.append({'Class': i,

                           'TP': tp,
   
                           'FN': fn,

                           'FP': fp,

                           'TN': tn})
         
        print('sensitivity', tp / tp + fn)

        print('specificity', tn / tn + fp)

    return counts_list


model= Sequential()
model.add(Conv1D(4, 6, strides=1,input_shape=(177,1)))
#model.add(Conv1D(4, 6, strides=1, padding='same'))
model.add(MaxPooling1D(4, strides=2))
model.add(Conv1D(4, 5, strides=1, padding='same'))
#model.add(Conv1D(4, 5, strides=1, padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(4, strides=2))
#model.add(Dropout(0.15))

model.add(Conv1D(10, 4,strides=1 , padding='same'))
#model.add(Conv1D(10, 4,strides=1 , padding='same'))

model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2))
#model.add(Dropout(0.15))
model.add(Conv1D(10, 4, strides=1 , padding='same'))
#model.add(Conv1D(10, 4, strides=1 , padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(10, strides=2))
#model.add(Dropout(0.15))

model.add(Conv1D(15, 4, strides=1 , padding='same'))
#model.add(Conv1D(15, 4, strides=1 , padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling1D(15, strides=2 , padding='same'))
#model.add(Dropout(0.15))

model.add(GlobalAveragePooling1D())
#model.add(Dropout(0.15))
model.add(Dense (50))
model.add(Dense (20))
model.add(Dense (5,activation='softmax'))
print(model.summary())



print("Number of columns in the dataframe: %i" % (X.shape[1]))
print("Number of rows in the dataframe: %i\n" % (X.shape[0]))
print("\n--- Create neural network model ---\n")
print(model.summary())
cvscores = []
j=1

kf=KFold(n_splits=5, random_state=None, shuffle=False)

scores = list()
# summarize scores
#def summarize_results(scores):
  #  m, s = mean(scores), std(scores)
 #   print('Accuracy: %.3f%%(+/-%.3f)' % (m ,s) )



for train_index, test_index in kf.split(X):
    print('\nFold ',j, "\n")
    print("Train Index: ", train_index.shape, "\n")
    print("Test Index: ", test_index.shape)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

   
    print("\n--- Reshape data to be accepted by Keras ---\n")
    X_train = np.reshape(X_train,(X_train.shape[0], X_train.shape[1],1))
    y_train = y_train.reshape(y_train.shape[0],1)
    y_train_hot = np_utils.to_categorical(y_train-1, 5) # subtracting y_train-1 as keras starts num_Classes index from 0 and we had it from 1 to 5
    print(X_train.shape)
    print(y_train_hot.shape)
    
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    print("\n--- Fit the model ---\n")
    history = model.fit(X_train, y_train_hot, batch_size = 400, epochs=20,
                        #callbacks=callbacks_list,
                        validation_split=0.2, verbose=1)
    

    predictions = model.predict(X_train)

    y_train_hot = np.argmax(y_train_hot, axis=-1)

    predictions = np.argmax(predictions, axis=-1)

    c = confusion_matrix(y_train_hot, predictions)
    
    print('Confusion matrix:\n', c)
    print(counts_from_confusion(c))
    show_confusion_matrix(y_train_hot, predictions)
    
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
    y_test = y_test.reshape(y_test.shape[0],1)
    
    y_test_hot = np_utils.to_categorical(y_test-1, 5)
   
    # evaluate the model
    print("\n--- evaluate the model ---\n")
    scores = model.evaluate(X_test, y_test_hot,verbose=1)
    
    predictions = model.predict(X_test)

    y_test_hot = np.argmax(y_test_hot, axis=-1)

    predictions = np.argmax(predictions, axis=-1)

    c = confusion_matrix(y_test_hot, predictions)

    print('Confusion matrix:\n', c)
    print(counts_from_confusion(c))
    show_confusion_matrix(y_test_hot, predictions)
    
    print("\n--- Learning curve of model training ---\n")
    plt.figure()
    plt.plot(history.history['acc'], "g--", label="Accuracy of training data")
    plt.plot(history.history['val_acc'], "g", label="Accuracy of validation data")
    plt.plot(history.history['loss'], "r--", label="Loss of training data")
    plt.plot(history.history['val_loss'], "r", label="Loss of validation data")

    plt.title('Model Accuracy and Loss')
    plt.legend()
    plt.show()

    cvscores.append(scores[1] * 100)
    j=j+1
print("Avarage accuracy :%.2f% %" , np.mean(cvscores))
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 172, 4)            28
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 85, 4)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 85, 4)             84
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 85, 4)             0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 41, 4)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 41, 10)            170
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 41, 10)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 16, 10)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 16, 10)            410
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 10)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 4, 10)             0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 4, 15)             615
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 4, 15)             0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 2, 15)             0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 15)                0
# _________________________________________________________________
# dense (Dense)                (None, 50)                800
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                1020
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 105
# =================================================================
# Total params: 3,232
# Trainable params: 3,232
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of columns in the dataframe: 177
# Number of rows in the dataframe: 11500
#
#
# --- Create neural network model ---
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 172, 4)            28
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 85, 4)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 85, 4)             84
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 85, 4)             0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 41, 4)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 41, 10)            170
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 41, 10)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 16, 10)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 16, 10)            410
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 10)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 4, 10)             0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 4, 15)             615
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 4, 15)             0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 2, 15)             0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 15)                0
# _________________________________________________________________
# dense (Dense)                (None, 50)                800
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                1020
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 105
# =================================================================
# Total params: 3,232
# Trainable params: 3,232
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Fold  1
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 2s 259us/step - loss: 6.1054 - acc: 0.2383 - val_loss: 4.6342 - val_acc: 0.2739
# Epoch 2/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 4.3648 - acc: 0.3266 - val_loss: 4.2910 - val_acc: 0.3418
# Epoch 3/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 4.1007 - acc: 0.3664 - val_loss: 4.2198 - val_acc: 0.3663
# Epoch 4/20
# 7360/7360 [==============================] - 0s 16us/step - loss: 4.0346 - acc: 0.3852 - val_loss: 4.1689 - val_acc: 0.3674
# Epoch 5/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 4.0027 - acc: 0.3965 - val_loss: 4.1391 - val_acc: 0.4016
# Epoch 6/20
# 7360/7360 [==============================] - 0s 16us/step - loss: 3.9761 - acc: 0.4103 - val_loss: 4.1197 - val_acc: 0.3995
# Epoch 7/20
# 7360/7360 [==============================] - 0s 16us/step - loss: 3.9562 - acc: 0.4227 - val_loss: 4.1048 - val_acc: 0.4207
# Epoch 8/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 3.9439 - acc: 0.4235 - val_loss: 4.0928 - val_acc: 0.4310
# Epoch 9/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 3.9304 - acc: 0.4355 - val_loss: 4.0637 - val_acc: 0.4315
# Epoch 10/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 3.8873 - acc: 0.4348 - val_loss: 3.4158 - val_acc: 0.3440
# Epoch 11/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 2.1062 - acc: 0.4020 - val_loss: 1.4856 - val_acc: 0.4511
# Epoch 12/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 1.3067 - acc: 0.4857 - val_loss: 1.1789 - val_acc: 0.5011
# Epoch 13/20
# 7360/7360 [==============================] - 0s 16us/step - loss: 1.1123 - acc: 0.5503 - val_loss: 1.0913 - val_acc: 0.5533
# Epoch 14/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 1.0265 - acc: 0.5727 - val_loss: 1.0260 - val_acc: 0.5717
# Epoch 15/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.9750 - acc: 0.5834 - val_loss: 0.9784 - val_acc: 0.5837
# Epoch 16/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.9400 - acc: 0.5986 - val_loss: 0.9432 - val_acc: 0.5875
# Epoch 17/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.9063 - acc: 0.6056 - val_loss: 0.9543 - val_acc: 0.5690
# Epoch 18/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.8842 - acc: 0.6143 - val_loss: 0.8931 - val_acc: 0.6136
# Epoch 19/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.8610 - acc: 0.6190 - val_loss: 0.9035 - val_acc: 0.5957
# Epoch 20/20
# 7360/7360 [==============================] - 0s 13us/step - loss: 0.8462 - acc: 0.6235 - val_loss: 0.8554 - val_acc: 0.6163
# Confusion matrix:
#  [[1703   85   11   37    8]
#  [  76 1009  582   23  158]
#  [  57  794  712   74  188]
#  [  38   18   28 1350  392]
#  [  18   74  125  612 1028]]
# sensitivity 142.0
# specificity 190.0
# sensitivity 840.0
# specificity 972.0
# sensitivity 1114.0
# specificity 747.0
# sensitivity 477.0
# specificity 747.0
# sensitivity 830.0
# specificity 747.0
# [{'Class': 0, 'TP': 1703, 'FN': 141.0, 'FP': 189.0, 'TN': 7167.0}, {'Class': 1, 'TP': 1009, 'FN': 839.0, 'FP': 971.0, 'TN': 6381.0}, {'Class': 2, 'TP': 712, 'FN': 1113.0, 'FP': 746.0, 'TN': 6629.0}, {'Class': 3, 'TP': 1350, 'FN': 476.0, 'FP': 746.0, 'TN': 6628.0}, {'Class': 4, 'TP': 1028, 'FN': 829.0, 'FP': 746.0, 'TN': 6597.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 44us/step
# Confusion matrix:
#  [[415  26   1  11   3]
#  [ 28 243 139   6  36]
#  [ 15 218 163  19  60]
#  [  8   4  11 352  99]
#  [  3  12  35 167 226]]
# sensitivity 42.0
# specificity 55.0
# sensitivity 210.0
# specificity 261.0
# sensitivity 313.0
# specificity 187.0
# sensitivity 123.0
# specificity 204.0
# sensitivity 218.0
# specificity 199.0
# [{'Class': 0, 'TP': 415, 'FN': 41.0, 'FP': 54.0, 'TN': 1790.0}, {'Class': 1, 'TP': 243, 'FN': 209.0, 'FP': 260.0, 'TN': 1588.0}, {'Class': 2, 'TP': 163, 'FN': 312.0, 'FP': 186.0, 'TN': 1639.0}, {'Class': 3, 'TP': 352, 'FN': 122.0, 'FP': 203.0, 'TN': 1623.0}, {'Class': 4, 'TP': 226, 'FN': 217.0, 'FP': 198.0, 'TN': 1659.0}]
# --- Learning curve of model training ---
# Fold  2
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 1s 91us/step - loss: 0.8634 - acc: 0.6061 - val_loss: 0.8422 - val_acc: 0.6223
# Epoch 2/20
# 7360/7360 [==============================] - 0s 13us/step - loss: 0.8209 - acc: 0.6336 - val_loss: 0.8219 - val_acc: 0.6261
# Epoch 3/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.7963 - acc: 0.6363 - val_loss: 0.8167 - val_acc: 0.6413
# Epoch 4/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.7762 - acc: 0.6518 - val_loss: 0.7858 - val_acc: 0.6473
# Epoch 5/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.7508 - acc: 0.6529 - val_loss: 0.7755 - val_acc: 0.6549
# Epoch 6/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.7382 - acc: 0.6583 - val_loss: 0.7644 - val_acc: 0.6511
# Epoch 7/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.7233 - acc: 0.6670 - val_loss: 0.7625 - val_acc: 0.6668
# Epoch 8/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.7151 - acc: 0.6670 - val_loss: 0.7418 - val_acc: 0.6663
# Epoch 9/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.7027 - acc: 0.6783 - val_loss: 0.7281 - val_acc: 0.6641
# Epoch 10/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6888 - acc: 0.6800 - val_loss: 0.7228 - val_acc: 0.6690
# Epoch 11/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6854 - acc: 0.6791 - val_loss: 0.7206 - val_acc: 0.6745
# Epoch 12/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6766 - acc: 0.6878 - val_loss: 0.7045 - val_acc: 0.6783
# Epoch 13/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6725 - acc: 0.6914 - val_loss: 0.7034 - val_acc: 0.6859
# Epoch 14/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.6650 - acc: 0.6887 - val_loss: 0.7026 - val_acc: 0.6766
# Epoch 15/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6665 - acc: 0.6920 - val_loss: 0.7118 - val_acc: 0.6707
# Epoch 16/20
# 7360/7360 [==============================] - 0s 16us/step - loss: 0.6699 - acc: 0.6860 - val_loss: 0.6925 - val_acc: 0.6853
# Epoch 17/20
# 7360/7360 [==============================] - 0s 17us/step - loss: 0.6509 - acc: 0.6988 - val_loss: 0.6859 - val_acc: 0.6859
# Epoch 18/20
# 7360/7360 [==============================] - 0s 16us/step - loss: 0.6399 - acc: 0.7050 - val_loss: 0.6894 - val_acc: 0.6918
# Epoch 19/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6373 - acc: 0.7019 - val_loss: 0.6869 - val_acc: 0.6853
# Epoch 20/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.6374 - acc: 0.7086 - val_loss: 0.6726 - val_acc: 0.6810
# Confusion matrix:
#  [[1760   58    9   22    1]
#  [  25 1010  647    5  142]
#  [  14  598  992   33  210]
#  [   2    9   23 1132  648]
#  [   0   46   83  153 1578]]
# sensitivity 91.0
# specificity 42.0
# sensitivity 820.0
# specificity 712.0
# sensitivity 856.0
# specificity 763.0
# sensitivity 683.0
# specificity 214.0
# sensitivity 283.0
# specificity 1002.0
# [{'Class': 0, 'TP': 1760, 'FN': 90.0, 'FP': 41.0, 'TN': 7309.0}, {'Class': 1, 'TP': 1010, 'FN': 819.0, 'FP': 711.0, 'TN': 6660.0}, {'Class': 2, 'TP': 992, 'FN': 855.0, 'FP': 762.0, 'TN': 6591.0}, {'Class': 3, 'TP': 1132, 'FN': 682.0, 'FP': 213.0, 'TN': 7173.0}, {'Class': 4, 'TP': 1578, 'FN': 282.0, 'FP': 1001.0, 'TN': 6339.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 40us/step
# Confusion matrix:
#  [[412  25   3  10   0]
#  [ 10 250 170   2  39]
#  [  3 149 239  12  50]
#  [  0   3   3 314 166]
#  [  0  12  29  28 371]]
# sensitivity 39.0
# specificity 14.0
# sensitivity 222.0
# specificity 190.0
# sensitivity 215.0
# specificity 206.0
# sensitivity 173.0
# specificity 53.0
# sensitivity 70.0
# specificity 256.0
# [{'Class': 0, 'TP': 412, 'FN': 38.0, 'FP': 13.0, 'TN': 1837.0}, {'Class': 1, 'TP': 250, 'FN': 221.0, 'FP': 189.0, 'TN': 1640.0}, {'Class': 2, 'TP': 239, 'FN': 214.0, 'FP': 205.0, 'TN': 1642.0}, {'Class': 3, 'TP': 314, 'FN': 172.0, 'FP': 52.0, 'TN': 1762.0}, {'Class': 4, 'TP': 371, 'FN': 69.0, 'FP': 255.0, 'TN': 1605.0}]
# --- Learning curve of model training ---
# Fold  3
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.6591 - acc: 0.6944 - val_loss: 0.6778 - val_acc: 0.6902
# Epoch 2/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6459 - acc: 0.7008 - val_loss: 0.6751 - val_acc: 0.6848
# Epoch 3/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6395 - acc: 0.7026 - val_loss: 0.6827 - val_acc: 0.6864
# Epoch 4/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6301 - acc: 0.7022 - val_loss: 0.6756 - val_acc: 0.6913
# Epoch 5/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6229 - acc: 0.7088 - val_loss: 0.6703 - val_acc: 0.6886
# Epoch 6/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6155 - acc: 0.7124 - val_loss: 0.6747 - val_acc: 0.6918
# Epoch 7/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6156 - acc: 0.7139 - val_loss: 0.6803 - val_acc: 0.6870
# Epoch 8/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.6174 - acc: 0.7135 - val_loss: 0.6722 - val_acc: 0.6880
# Epoch 9/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.6104 - acc: 0.7128 - val_loss: 0.6621 - val_acc: 0.6913
# Epoch 10/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.6103 - acc: 0.7152 - val_loss: 0.6754 - val_acc: 0.6815
# Epoch 11/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6121 - acc: 0.7151 - val_loss: 0.6566 - val_acc: 0.6989
# Epoch 12/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5956 - acc: 0.7188 - val_loss: 0.6603 - val_acc: 0.6929
# Epoch 13/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5964 - acc: 0.7213 - val_loss: 0.6703 - val_acc: 0.6897
# Epoch 14/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.6014 - acc: 0.7143 - val_loss: 0.6664 - val_acc: 0.6946
# Epoch 15/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5852 - acc: 0.7273 - val_loss: 0.6569 - val_acc: 0.6935
# Epoch 16/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5828 - acc: 0.7250 - val_loss: 0.6569 - val_acc: 0.6962
# Epoch 17/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5833 - acc: 0.7265 - val_loss: 0.6565 - val_acc: 0.6951
# Epoch 18/20
# 7360/7360 [==============================] - 0s 16us/step - loss: 0.5808 - acc: 0.7276 - val_loss: 0.6693 - val_acc: 0.6957
# Epoch 19/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5773 - acc: 0.7245 - val_loss: 0.6510 - val_acc: 0.6973
# Epoch 20/20
# 7360/7360 [==============================] - 0s 16us/step - loss: 0.5749 - acc: 0.7264 - val_loss: 0.6537 - val_acc: 0.7000
# Confusion matrix:
#  [[1783   35    3   11    0]
#  [  46  913  724   13  120]
#  [  20  494 1119   57  162]
#  [   3    8   21 1424  393]
#  [   1   44   78  276 1452]]
# sensitivity 50.0
# specificity 71.0
# sensitivity 904.0
# specificity 582.0
# sensitivity 734.0
# specificity 827.0
# sensitivity 426.0
# specificity 358.0
# sensitivity 400.0
# specificity 676.0
# [{'Class': 0, 'TP': 1783, 'FN': 49.0, 'FP': 70.0, 'TN': 7298.0}, {'Class': 1, 'TP': 913, 'FN': 903.0, 'FP': 581.0, 'TN': 6803.0}, {'Class': 2, 'TP': 1119, 'FN': 733.0, 'FP': 826.0, 'TN': 6522.0}, {'Class': 3, 'TP': 1424, 'FN': 425.0, 'FP': 357.0, 'TN': 6994.0}, {'Class': 4, 'TP': 1452, 'FN': 399.0, 'FP': 675.0, 'TN': 6674.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 43us/step
# Confusion matrix:
#  [[458   5   4   1   0]
#  [ 11 240 192   4  37]
#  [  6 123 270  14  35]
#  [  1   2   3 333 112]
#  [  0  12  20  58 359]]
# sensitivity 11.0
# specificity 19.0
# sensitivity 245.0
# specificity 143.0
# sensitivity 179.0
# specificity 220.0
# sensitivity 119.0
# specificity 78.0
# sensitivity 91.0
# specificity 185.0
# [{'Class': 0, 'TP': 458, 'FN': 10.0, 'FP': 18.0, 'TN': 1814.0}, {'Class': 1, 'TP': 240, 'FN': 244.0, 'FP': 142.0, 'TN': 1674.0}, {'Class': 2, 'TP': 270, 'FN': 178.0, 'FP': 219.0, 'TN': 1633.0}, {'Class': 3, 'TP': 333, 'FN': 118.0, 'FP': 77.0, 'TN': 1772.0}, {'Class': 4, 'TP': 359, 'FN': 90.0, 'FP': 184.0, 'TN': 1667.0}]
# --- Learning curve of model training ---
# Fold  4
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 1s 105us/step - loss: 0.5996 - acc: 0.7166 - val_loss: 0.7031 - val_acc: 0.6870
# Epoch 2/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5953 - acc: 0.7173 - val_loss: 0.6620 - val_acc: 0.6978
# Epoch 3/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5804 - acc: 0.7202 - val_loss: 0.6444 - val_acc: 0.6989
# Epoch 4/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5704 - acc: 0.7283 - val_loss: 0.6408 - val_acc: 0.7011
# Epoch 5/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5668 - acc: 0.7334 - val_loss: 0.6425 - val_acc: 0.7033
# Epoch 6/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5658 - acc: 0.7296 - val_loss: 0.6452 - val_acc: 0.7022
# Epoch 7/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5641 - acc: 0.7355 - val_loss: 0.6429 - val_acc: 0.7022
# Epoch 8/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5604 - acc: 0.7337 - val_loss: 0.6389 - val_acc: 0.7038
# Epoch 9/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5618 - acc: 0.7393 - val_loss: 0.6404 - val_acc: 0.7120
# Epoch 10/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5581 - acc: 0.7336 - val_loss: 0.6496 - val_acc: 0.7109
# Epoch 11/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5561 - acc: 0.7351 - val_loss: 0.6400 - val_acc: 0.7016
# Epoch 12/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5641 - acc: 0.7356 - val_loss: 0.6580 - val_acc: 0.7016
# Epoch 13/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5624 - acc: 0.7292 - val_loss: 0.6450 - val_acc: 0.7141
# Epoch 14/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5501 - acc: 0.7410 - val_loss: 0.6547 - val_acc: 0.7033
# Epoch 15/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5541 - acc: 0.7394 - val_loss: 0.6349 - val_acc: 0.7179
# Epoch 16/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5479 - acc: 0.7428 - val_loss: 0.6313 - val_acc: 0.7141
# Epoch 17/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5431 - acc: 0.7458 - val_loss: 0.6372 - val_acc: 0.7163
# Epoch 18/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5416 - acc: 0.7435 - val_loss: 0.6460 - val_acc: 0.7103
# Epoch 19/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5401 - acc: 0.7490 - val_loss: 0.6360 - val_acc: 0.7174
# Epoch 20/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5399 - acc: 0.7481 - val_loss: 0.6365 - val_acc: 0.7158
# Confusion matrix:
#  [[1790   35    9    5    0]
#  [  24  959  740   11  100]
#  [  17  440 1227   48  102]
#  [   0   13   22 1502  318]
#  [   1   49   69  334 1385]]
# sensitivity 50.0
# specificity 43.0
# sensitivity 876.0
# specificity 538.0
# sensitivity 608.0
# specificity 841.0
# sensitivity 354.0
# specificity 399.0
# sensitivity 454.0
# specificity 521.0
# [{'Class': 0, 'TP': 1790, 'FN': 49.0, 'FP': 42.0, 'TN': 7319.0}, {'Class': 1, 'TP': 959, 'FN': 875.0, 'FP': 537.0, 'TN': 6829.0}, {'Class': 2, 'TP': 1227, 'FN': 607.0, 'FP': 840.0, 'TN': 6526.0}, {'Class': 3, 'TP': 1502, 'FN': 353.0, 'FP': 398.0, 'TN': 6947.0}, {'Class': 4, 'TP': 1385, 'FN': 453.0, 'FP': 520.0, 'TN': 6842.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 42us/step
# Confusion matrix:
#  [[447   6   4   4   0]
#  [ 15 222 201   0  28]
#  [  3 122 300  17  24]
#  [  0   5  13 344  83]
#  [  0   8  30  83 341]]
# sensitivity 15.0
# specificity 19.0
# sensitivity 245.0
# specificity 142.0
# sensitivity 167.0
# specificity 249.0
# sensitivity 102.0
# specificity 105.0
# sensitivity 122.0
# specificity 136.0
# [{'Class': 0, 'TP': 447, 'FN': 14.0, 'FP': 18.0, 'TN': 1821.0}, {'Class': 1, 'TP': 222, 'FN': 244.0, 'FP': 141.0, 'TN': 1693.0}, {'Class': 2, 'TP': 300, 'FN': 166.0, 'FP': 248.0, 'TN': 1586.0}, {'Class': 3, 'TP': 344, 'FN': 101.0, 'FP': 104.0, 'TN': 1751.0}, {'Class': 4, 'TP': 341, 'FN': 121.0, 'FP': 135.0, 'TN': 1703.0}]
# --- Learning curve of model training ---
# Fold  5
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 1s 115us/step - loss: 0.5621 - acc: 0.7345 - val_loss: 0.6141 - val_acc: 0.7120
# Epoch 2/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5447 - acc: 0.7467 - val_loss: 0.6040 - val_acc: 0.7223
# Epoch 3/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5323 - acc: 0.7462 - val_loss: 0.5996 - val_acc: 0.7293
# Epoch 4/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5348 - acc: 0.7478 - val_loss: 0.6075 - val_acc: 0.7136
# Epoch 5/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5321 - acc: 0.7462 - val_loss: 0.6024 - val_acc: 0.7179
# Epoch 6/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5276 - acc: 0.7508 - val_loss: 0.6110 - val_acc: 0.7272
# Epoch 7/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5269 - acc: 0.7503 - val_loss: 0.6038 - val_acc: 0.7266
# Epoch 8/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5297 - acc: 0.7511 - val_loss: 0.6025 - val_acc: 0.7288
# Epoch 9/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5275 - acc: 0.7553 - val_loss: 0.6060 - val_acc: 0.7299
# Epoch 10/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5254 - acc: 0.7534 - val_loss: 0.6086 - val_acc: 0.7277
# Epoch 11/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5173 - acc: 0.7590 - val_loss: 0.6169 - val_acc: 0.7234
# Epoch 12/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5202 - acc: 0.7546 - val_loss: 0.6064 - val_acc: 0.7228
# Epoch 13/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5251 - acc: 0.7511 - val_loss: 0.6103 - val_acc: 0.7283
# Epoch 14/20
# 7360/7360 [==============================] - 0s 16us/step - loss: 0.5251 - acc: 0.7512 - val_loss: 0.6329 - val_acc: 0.7114
# Epoch 15/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5269 - acc: 0.7481 - val_loss: 0.6063 - val_acc: 0.7304
# Epoch 16/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5189 - acc: 0.7569 - val_loss: 0.6292 - val_acc: 0.7125
# Epoch 17/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5186 - acc: 0.7594 - val_loss: 0.6092 - val_acc: 0.7207
# Epoch 18/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5062 - acc: 0.7652 - val_loss: 0.6105 - val_acc: 0.7310
# Epoch 19/20
# 7360/7360 [==============================] - 0s 15us/step - loss: 0.5094 - acc: 0.7630 - val_loss: 0.6162 - val_acc: 0.7163
# Epoch 20/20
# 7360/7360 [==============================] - 0s 14us/step - loss: 0.5083 - acc: 0.7626 - val_loss: 0.6117 - val_acc: 0.7163
# Confusion matrix:
#  [[1787   34   10    4    0]
#  [  17 1383  350   12  111]
#  [  11  814  853   48  116]
#  [   0   19   21 1474  342]
#  [   1   39   41  288 1425]]
# sensitivity 49.0
# specificity 30.0
# sensitivity 491.0
# specificity 907.0
# sensitivity 990.0
# specificity 423.0
# sensitivity 383.0
# specificity 353.0
# sensitivity 370.0
# specificity 570.0
# [{'Class': 0, 'TP': 1787, 'FN': 48.0, 'FP': 29.0, 'TN': 7336.0}, {'Class': 1, 'TP': 1383, 'FN': 490.0, 'FP': 906.0, 'TN': 6421.0}, {'Class': 2, 'TP': 853, 'FN': 989.0, 'FP': 422.0, 'TN': 6936.0}, {'Class': 3, 'TP': 1474, 'FN': 382.0, 'FP': 352.0, 'TN': 6992.0}, {'Class': 4, 'TP': 1425, 'FN': 369.0, 'FP': 569.0, 'TN': 6837.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 45us/step
# Confusion matrix:
#  [[442  15   3   4   1]
#  [ 10 278 102   3  34]
#  [  3 222 185  15  33]
#  [  1   4   7 354  78]
#  [  0  19  15  76 396]]
# sensitivity 24.0
# specificity 15.0
# sensitivity 150.0
# specificity 261.0
# sensitivity 274.0
# specificity 128.0
# sensitivity 91.0
# specificity 99.0
# sensitivity 111.0
# specificity 147.0
# [{'Class': 0, 'TP': 442, 'FN': 23.0, 'FP': 14.0, 'TN': 1821.0}, {'Class': 1, 'TP': 278, 'FN': 149.0, 'FP': 260.0, 'TN': 1613.0}, {'Class': 2, 'TP': 185, 'FN': 273.0, 'FP': 127.0, 'TN': 1715.0}, {'Class': 3, 'TP': 354, 'FN': 90.0, 'FP': 98.0, 'TN': 1758.0}, {'Class': 4, 'TP': 396, 'FN': 110.0, 'FP': 146.0, 'TN': 1648.0}]
# --- Learning curve of model training ---
# Avarage accuracy :%.2f% % 69.16521739130435
