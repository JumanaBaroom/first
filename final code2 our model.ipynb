# %%
import sys
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from numpy.random import seed
from tensorflow import set_random_seed
import scipy as sp
import scipy.io as spio
from matplotlib import pyplot as plt
import matplotlib.pylab as pl
# %matplotlib inline
from tensorflow.python import keras
from sklearn.model_selection import train_test_split ,KFold
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.layers import Dense, Flatten, Conv1D, Dropout, MaxPooling1D, Reshape, GlobalAveragePooling1D
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.layers import LeakyReLU

from numpy import mean
from numpy import std
import pandas as pd
from scipy import stats
from scipy.stats import zscore
from scipy import stats
from sklearn import metrics
import keras.backend as k
import seaborn as sns
from sklearn import preprocessing
from numpy import mean
from numpy import std

from scipy import stats
from scipy.stats import zscore
from keras.constraints import max_norm


dataset = np.loadtxt("datalast.csv",delimiter=",")

def feature_normalize(dataset):

    mu = np.mean(dataset, axis=0)
    sigma = np.std(dataset, axis=0)
    z=(dataset - mu)/sigma
    dataset=stats.zscore(z)
    return (dataset)

feature_normalize(dataset)

X = dataset[:,0:177]
y = dataset[:,178]



LABELS = ["0",

          "1",

          "2",

          "3",

          "4"]

 

def show_confusion_matrix(validations, predictions):
 

    #matrix = metrics.confusion_matrix(y_test_hot, predictions)

    plt.figure(figsize=(6, 4))

    sns.heatmap(c,

                cmap="coolwarm",

                linecolor='white',

                linewidths=1,

                xticklabels=LABELS,

                yticklabels=LABELS,

                annot=True,

                fmt="d")

    plt.title("Confusion Matrix")

    plt.ylabel("True Label")

    plt.xlabel("Predicted Label")

    plt.show()
    
def counts_from_confusion(confusion):

    counts_list=[]
    
# Iterate through classes and store the counts

    for i in range(confusion.shape[0]):

        tp = confusion[i, i]
        
        fn_mask = np.zeros(confusion.shape)

        fn_mask[i, :] = 1

        fn_mask[i, i] = 0

        fn = np.sum(np.multiply(confusion, fn_mask))



        fp_mask = np.zeros(confusion.shape)

        fp_mask[:, i] = 1

        fp_mask[i, i] = 0

        fp = np.sum(np.multiply(confusion, fp_mask))
        
        tn_mask = 1 - (fn_mask + fp_mask)

        tn_mask[i, i] = 0

        tn = np.sum(np.multiply(confusion, tn_mask))



        counts_list.append({'Class': i,

                           'TP': tp,
   
                           'FN': fn,

                           'FP': fp,

                           'TN': tn})
         
        print('sensitivity', tp / tp + fn)

        print('specificity', tn / tn + fp)

    return counts_list


model = Sequential()
model.add(Conv1D(60, 10, activation='relu', input_shape=(177,1)))
model.add(Conv1D(60, 10, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.05))
model.add(Conv1D(100, 10, activation='relu'))
model.add(Conv1D(100, 10, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Dropout(0.15))
model.add(Conv1D(50, 5, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.05))
model.add(Dense(5, activation='softmax'))
print(model.summary())


print("Number of columns in the dataframe: %i" % (X.shape[1]))
print("Number of rows in the dataframe: %i\n" % (X.shape[0]))
print("\n--- Create neural network model ---\n")
print(model.summary())
cvscores = []
j=1

kf=KFold(n_splits=5, random_state=None, shuffle=False)

scores = list()
# summarize scores
#def summarize_results(scores):
  #  m, s = mean(scores), std(scores)
 #   print('Accuracy: %.3f%%(+/-%.3f)' % (m ,s) )



for train_index, test_index in kf.split(X):
    print('\nFold ',j, "\n")
    print("Train Index: ", train_index.shape, "\n")
    print("Test Index: ", test_index.shape)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

   
    print("\n--- Reshape data to be accepted by Keras ---\n")
    X_train = np.reshape(X_train,(X_train.shape[0], X_train.shape[1],1))
    y_train = y_train.reshape(y_train.shape[0],1)
    y_train_hot = np_utils.to_categorical(y_train-1, 5) # subtracting y_train-1 as keras starts num_Classes index from 0 and we had it from 1 to 5
    print(X_train.shape)
    print(y_train_hot.shape)
    
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    print("\n--- Fit the model ---\n")
    history = model.fit(X_train, y_train_hot, batch_size = 400, epochs=20,
                        #callbacks=callbacks_list,
                        validation_split=0.2, verbose=1)
    

    predictions = model.predict(X_train)

    y_train_hot = np.argmax(y_train_hot, axis=-1)

    predictions = np.argmax(predictions, axis=-1)

    c = confusion_matrix(y_train_hot, predictions)
    
    print('Confusion matrix:\n', c)
    print(counts_from_confusion(c))
    show_confusion_matrix(y_train_hot, predictions)
    
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
    y_test = y_test.reshape(y_test.shape[0],1)
    
    y_test_hot = np_utils.to_categorical(y_test-1, 5)
   
    # evaluate the model
    print("\n--- evaluate the model ---\n")
    scores = model.evaluate(X_test, y_test_hot,verbose=1)
    
    predictions = model.predict(X_test)

    y_test_hot = np.argmax(y_test_hot, axis=-1)

    predictions = np.argmax(predictions, axis=-1)

    c = confusion_matrix(y_test_hot, predictions)

    print('Confusion matrix:\n', c)
    print(counts_from_confusion(c))
    show_confusion_matrix(y_test_hot, predictions)
    
    print("\n--- Learning curve of model training ---\n")
    plt.figure()
    plt.plot(history.history['acc'], "g--", label="Accuracy of training data")
    plt.plot(history.history['val_acc'], "g", label="Accuracy of validation data")
    plt.plot(history.history['loss'], "r--", label="Loss of training data")
    plt.plot(history.history['val_loss'], "r", label="Loss of validation data")

    plt.title('Model Accuracy and Loss')
    plt.legend()
    plt.show()

    cvscores.append(scores[1] * 100)
    j=j+1
print("Avarage accuracy :%.2f% %" , np.mean(cvscores))
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 168, 60)           660
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 159, 60)           36060
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 79, 60)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 79, 60)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 70, 100)           60100
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 61, 100)           100100
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 30, 100)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 100)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 26, 50)            25050
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 50)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 255
# =================================================================
# Total params: 222,225
# Trainable params: 222,225
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of columns in the dataframe: 177
# Number of rows in the dataframe: 11500
#
#
# --- Create neural network model ---
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 168, 60)           660
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 159, 60)           36060
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 79, 60)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 79, 60)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 70, 100)           60100
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 61, 100)           100100
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 30, 100)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 100)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 26, 50)            25050
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 50)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 255
# =================================================================
# Total params: 222,225
# Trainable params: 222,225
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Fold  1
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 4s 479us/step - loss: 2.9083 - acc: 0.2427 - val_loss: 1.3683 - val_acc: 0.2076
# Epoch 2/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 1.2808 - acc: 0.3288 - val_loss: 1.1487 - val_acc: 0.4620
# Epoch 3/20
# 7360/7360 [==============================] - 1s 92us/step - loss: 1.0618 - acc: 0.5273 - val_loss: 1.0000 - val_acc: 0.6027
# Epoch 4/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.9493 - acc: 0.5897 - val_loss: 0.8526 - val_acc: 0.6266
# Epoch 5/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.9055 - acc: 0.5924 - val_loss: 0.8314 - val_acc: 0.6337
# Epoch 6/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.8503 - acc: 0.6208 - val_loss: 0.7908 - val_acc: 0.6549
# Epoch 7/20
# 7360/7360 [==============================] - 1s 92us/step - loss: 0.7961 - acc: 0.6420 - val_loss: 0.7551 - val_acc: 0.6511
# Epoch 8/20
# 7360/7360 [==============================] - 1s 92us/step - loss: 0.7692 - acc: 0.6503 - val_loss: 0.7304 - val_acc: 0.6810
# Epoch 9/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.7372 - acc: 0.6689 - val_loss: 0.7166 - val_acc: 0.6772
# Epoch 10/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.7179 - acc: 0.6758 - val_loss: 0.7016 - val_acc: 0.6793
# Epoch 11/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.6891 - acc: 0.6832 - val_loss: 0.6718 - val_acc: 0.6946
# Epoch 12/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.6701 - acc: 0.6955 - val_loss: 0.6463 - val_acc: 0.7087
# Epoch 13/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.6882 - acc: 0.6846 - val_loss: 0.6454 - val_acc: 0.7103
# Epoch 14/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.6558 - acc: 0.7016 - val_loss: 0.6402 - val_acc: 0.7060
# Epoch 15/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.6518 - acc: 0.7024 - val_loss: 0.6373 - val_acc: 0.7060
# Epoch 16/20
# 7360/7360 [==============================] - 1s 93us/step - loss: 0.6176 - acc: 0.7126 - val_loss: 0.6237 - val_acc: 0.7168
# Epoch 17/20
# 7360/7360 [==============================] - 1s 93us/step - loss: 0.5973 - acc: 0.7264 - val_loss: 0.5836 - val_acc: 0.7342
# Epoch 18/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.5982 - acc: 0.7177 - val_loss: 0.6344 - val_acc: 0.6962
# Epoch 19/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.5918 - acc: 0.7260 - val_loss: 0.5913 - val_acc: 0.7239
# Epoch 20/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.5644 - acc: 0.7376 - val_loss: 0.6023 - val_acc: 0.7272
# Confusion matrix:
#  [[1707  105    9   21    2]
#  [  11 1108  655    9   65]
#  [   2  546 1129   37  111]
#  [   0   27   15 1554  230]
#  [   0   62   93  339 1363]]
# sensitivity 138.0
# specificity 14.0
# sensitivity 741.0
# specificity 741.0
# sensitivity 697.0
# specificity 773.0
# sensitivity 273.0
# specificity 407.0
# sensitivity 495.0
# specificity 409.0
# [{'Class': 0, 'TP': 1707, 'FN': 137.0, 'FP': 13.0, 'TN': 7343.0}, {'Class': 1, 'TP': 1108, 'FN': 740.0, 'FP': 740.0, 'TN': 6612.0}, {'Class': 2, 'TP': 1129, 'FN': 696.0, 'FP': 772.0, 'TN': 6603.0}, {'Class': 3, 'TP': 1554, 'FN': 272.0, 'FP': 406.0, 'TN': 6968.0}, {'Class': 4, 'TP': 1363, 'FN': 494.0, 'FP': 408.0, 'TN': 6935.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 155us/step
# Confusion matrix:
#  [[416  29   1  10   0]
#  [  4 248 180   4  16]
#  [  0 145 283  14  33]
#  [  0   6   3 390  75]
#  [  0  15  29  90 309]]
# sensitivity 41.0
# specificity 5.0
# sensitivity 205.0
# specificity 196.0
# sensitivity 193.0
# specificity 214.0
# sensitivity 85.0
# specificity 119.0
# sensitivity 135.0
# specificity 125.0
# [{'Class': 0, 'TP': 416, 'FN': 40.0, 'FP': 4.0, 'TN': 1840.0}, {'Class': 1, 'TP': 248, 'FN': 204.0, 'FP': 195.0, 'TN': 1653.0}, {'Class': 2, 'TP': 283, 'FN': 192.0, 'FP': 213.0, 'TN': 1612.0}, {'Class': 3, 'TP': 390, 'FN': 84.0, 'FP': 118.0, 'TN': 1708.0}, {'Class': 4, 'TP': 309, 'FN': 134.0, 'FP': 124.0, 'TN': 1733.0}]
# --- Learning curve of model training ---
# Fold  2
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 1s 165us/step - loss: 0.6857 - acc: 0.6844 - val_loss: 0.6129 - val_acc: 0.7152
# Epoch 2/20
# 7360/7360 [==============================] - 1s 97us/step - loss: 0.5743 - acc: 0.7291 - val_loss: 0.5918 - val_acc: 0.7228
# Epoch 3/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.5456 - acc: 0.7488 - val_loss: 0.5411 - val_acc: 0.7511
# Epoch 4/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.5156 - acc: 0.7618 - val_loss: 0.5339 - val_acc: 0.7511
# Epoch 5/20
# 7360/7360 [==============================] - 1s 93us/step - loss: 0.5305 - acc: 0.7514 - val_loss: 0.5276 - val_acc: 0.7565
# Epoch 6/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.5024 - acc: 0.7639 - val_loss: 0.5307 - val_acc: 0.7560
# Epoch 7/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.5032 - acc: 0.7668 - val_loss: 0.5257 - val_acc: 0.7592
# Epoch 8/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.4903 - acc: 0.7692 - val_loss: 0.5730 - val_acc: 0.7435
# Epoch 9/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.4884 - acc: 0.7693 - val_loss: 0.5175 - val_acc: 0.7668
# Epoch 10/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.4496 - acc: 0.7894 - val_loss: 0.4964 - val_acc: 0.7674
# Epoch 11/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.4581 - acc: 0.7857 - val_loss: 0.4967 - val_acc: 0.7755
# Epoch 12/20
# 7360/7360 [==============================] - 1s 93us/step - loss: 0.4291 - acc: 0.7951 - val_loss: 0.4748 - val_acc: 0.7848
# Epoch 13/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.4245 - acc: 0.7985 - val_loss: 0.5161 - val_acc: 0.7511
# Epoch 14/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.4308 - acc: 0.7993 - val_loss: 0.4995 - val_acc: 0.7750
# Epoch 15/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.4171 - acc: 0.8084 - val_loss: 0.4775 - val_acc: 0.7832
# Epoch 16/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.4033 - acc: 0.8105 - val_loss: 0.4932 - val_acc: 0.7810
# Epoch 17/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3861 - acc: 0.8202 - val_loss: 0.5370 - val_acc: 0.7603
# Epoch 18/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.4299 - acc: 0.8015 - val_loss: 0.4570 - val_acc: 0.7924
# Epoch 19/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3957 - acc: 0.8086 - val_loss: 0.4950 - val_acc: 0.7712
# Epoch 20/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3796 - acc: 0.8266 - val_loss: 0.4670 - val_acc: 0.7935
# Confusion matrix:
#  [[1809   27    5    7    2]
#  [   1 1371  381    6   70]
#  [   0  500 1241    6  100]
#  [   0    1    1 1576  236]
#  [   0   23   33   73 1731]]
# sensitivity 42.0
# specificity 2.0
# sensitivity 459.0
# specificity 552.0
# sensitivity 607.0
# specificity 421.0
# sensitivity 239.0
# specificity 93.0
# sensitivity 130.0
# specificity 409.0
# [{'Class': 0, 'TP': 1809, 'FN': 41.0, 'FP': 1.0, 'TN': 7349.0}, {'Class': 1, 'TP': 1371, 'FN': 458.0, 'FP': 551.0, 'TN': 6820.0}, {'Class': 2, 'TP': 1241, 'FN': 606.0, 'FP': 420.0, 'TN': 6933.0}, {'Class': 3, 'TP': 1576, 'FN': 238.0, 'FP': 92.0, 'TN': 7294.0}, {'Class': 4, 'TP': 1731, 'FN': 129.0, 'FP': 408.0, 'TN': 6932.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 48us/step
# Confusion matrix:
#  [[431  13   5   1   0]
#  [  3 306 145   2  15]
#  [  0 148 270   2  33]
#  [  0   0   2 410  74]
#  [  0   7   8  28 397]]
# sensitivity 20.0
# specificity 4.0
# sensitivity 166.0
# specificity 169.0
# sensitivity 184.0
# specificity 161.0
# sensitivity 77.0
# specificity 34.0
# sensitivity 44.0
# specificity 123.0
# [{'Class': 0, 'TP': 431, 'FN': 19.0, 'FP': 3.0, 'TN': 1847.0}, {'Class': 1, 'TP': 306, 'FN': 165.0, 'FP': 168.0, 'TN': 1661.0}, {'Class': 2, 'TP': 270, 'FN': 183.0, 'FP': 160.0, 'TN': 1687.0}, {'Class': 3, 'TP': 410, 'FN': 76.0, 'FP': 33.0, 'TN': 1781.0}, {'Class': 4, 'TP': 397, 'FN': 43.0, 'FP': 122.0, 'TN': 1738.0}]
# --- Learning curve of model training ---
# Fold  3
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 1s 169us/step - loss: 0.5895 - acc: 0.7361 - val_loss: 0.4971 - val_acc: 0.7728
# Epoch 2/20
# 7360/7360 [==============================] - 1s 92us/step - loss: 0.4504 - acc: 0.7921 - val_loss: 0.4961 - val_acc: 0.7804
# Epoch 3/20
# 7360/7360 [==============================] - 1s 92us/step - loss: 0.4056 - acc: 0.8166 - val_loss: 0.4359 - val_acc: 0.8000
# Epoch 4/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3745 - acc: 0.8255 - val_loss: 0.4560 - val_acc: 0.7978
# Epoch 5/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.3650 - acc: 0.8340 - val_loss: 0.4396 - val_acc: 0.8000
# Epoch 6/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3611 - acc: 0.8332 - val_loss: 0.4410 - val_acc: 0.8054
# Epoch 7/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3480 - acc: 0.8394 - val_loss: 0.4384 - val_acc: 0.7908
# Epoch 8/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3300 - acc: 0.8530 - val_loss: 0.4294 - val_acc: 0.8082
# Epoch 9/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3332 - acc: 0.8470 - val_loss: 0.4325 - val_acc: 0.8033
# Epoch 10/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.3191 - acc: 0.8548 - val_loss: 0.4609 - val_acc: 0.8065
# Epoch 11/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3215 - acc: 0.8576 - val_loss: 0.4541 - val_acc: 0.7902
# Epoch 12/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.3146 - acc: 0.8635 - val_loss: 0.4228 - val_acc: 0.8071
# Epoch 13/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.2966 - acc: 0.8734 - val_loss: 0.5711 - val_acc: 0.7712
# Epoch 14/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3996 - acc: 0.8281 - val_loss: 0.5236 - val_acc: 0.7652
# Epoch 15/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.3311 - acc: 0.8529 - val_loss: 0.4354 - val_acc: 0.8082
# Epoch 16/20
# 7360/7360 [==============================] - 1s 97us/step - loss: 0.2844 - acc: 0.8804 - val_loss: 0.4265 - val_acc: 0.8147
# Epoch 17/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.2752 - acc: 0.8798 - val_loss: 0.4567 - val_acc: 0.7935
# Epoch 18/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.2659 - acc: 0.8846 - val_loss: 0.4707 - val_acc: 0.8038
# Epoch 19/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.2578 - acc: 0.8950 - val_loss: 0.4488 - val_acc: 0.8071
# Epoch 20/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.2475 - acc: 0.8929 - val_loss: 0.4422 - val_acc: 0.7995
# Confusion matrix:
#  [[1802   25    2    3    0]
#  [   1 1653  154    0    8]
#  [   0  510 1328    1   13]
#  [   0    4    3 1707  135]
#  [   0   29   25   49 1748]]
# sensitivity 31.0
# specificity 2.0
# sensitivity 164.0
# specificity 569.0
# sensitivity 525.0
# specificity 185.0
# sensitivity 143.0
# specificity 54.0
# sensitivity 104.0
# specificity 157.0
# [{'Class': 0, 'TP': 1802, 'FN': 30.0, 'FP': 1.0, 'TN': 7367.0}, {'Class': 1, 'TP': 1653, 'FN': 163.0, 'FP': 568.0, 'TN': 6816.0}, {'Class': 2, 'TP': 1328, 'FN': 524.0, 'FP': 184.0, 'TN': 7164.0}, {'Class': 3, 'TP': 1707, 'FN': 142.0, 'FP': 53.0, 'TN': 7298.0}, {'Class': 4, 'TP': 1748, 'FN': 103.0, 'FP': 156.0, 'TN': 7193.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 48us/step
# Confusion matrix:
#  [[464   3   1   0   0]
#  [  0 415  66   0   3]
#  [  1 176 262   2   7]
#  [  0   1   0 401  49]
#  [  0  13  12  32 392]]
# sensitivity 5.0
# specificity 2.0
# sensitivity 70.0
# specificity 194.0
# sensitivity 187.0
# specificity 80.0
# sensitivity 51.0
# specificity 35.0
# sensitivity 58.0
# specificity 60.0
# [{'Class': 0, 'TP': 464, 'FN': 4.0, 'FP': 1.0, 'TN': 1831.0}, {'Class': 1, 'TP': 415, 'FN': 69.0, 'FP': 193.0, 'TN': 1623.0}, {'Class': 2, 'TP': 262, 'FN': 186.0, 'FP': 79.0, 'TN': 1773.0}, {'Class': 3, 'TP': 401, 'FN': 50.0, 'FP': 34.0, 'TN': 1815.0}, {'Class': 4, 'TP': 392, 'FN': 57.0, 'FP': 59.0, 'TN': 1792.0}]
# --- Learning curve of model training ---
# Fold  4
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 1s 178us/step - loss: 0.5258 - acc: 0.7815 - val_loss: 0.4725 - val_acc: 0.7897
# Epoch 2/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.3436 - acc: 0.8489 - val_loss: 0.4128 - val_acc: 0.8076
# Epoch 3/20
# 7360/7360 [==============================] - 1s 93us/step - loss: 0.2882 - acc: 0.8730 - val_loss: 0.4210 - val_acc: 0.8190
# Epoch 4/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.2622 - acc: 0.8868 - val_loss: 0.4181 - val_acc: 0.8185
# Epoch 5/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.2460 - acc: 0.8943 - val_loss: 0.4331 - val_acc: 0.8082
# Epoch 6/20
# 7360/7360 [==============================] - 1s 93us/step - loss: 0.2445 - acc: 0.8942 - val_loss: 0.4536 - val_acc: 0.8065
# Epoch 7/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.2415 - acc: 0.8917 - val_loss: 0.4693 - val_acc: 0.8092
# Epoch 8/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.2428 - acc: 0.8943 - val_loss: 0.5179 - val_acc: 0.7848
# Epoch 9/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.2303 - acc: 0.8996 - val_loss: 0.4630 - val_acc: 0.8054
# Epoch 10/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.2273 - acc: 0.9041 - val_loss: 0.4878 - val_acc: 0.8027
# Epoch 11/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.2069 - acc: 0.9125 - val_loss: 0.4402 - val_acc: 0.8196
# Epoch 12/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.2022 - acc: 0.9148 - val_loss: 0.4662 - val_acc: 0.8136
# Epoch 13/20
# 7360/7360 [==============================] - 1s 92us/step - loss: 0.2007 - acc: 0.9167 - val_loss: 0.4609 - val_acc: 0.8125
# Epoch 14/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.1915 - acc: 0.9240 - val_loss: 0.4884 - val_acc: 0.8038
# Epoch 15/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.1819 - acc: 0.9260 - val_loss: 0.4709 - val_acc: 0.8125
# Epoch 16/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.1735 - acc: 0.9270 - val_loss: 0.5312 - val_acc: 0.8005
# Epoch 17/20
# 7360/7360 [==============================] - 1s 92us/step - loss: 0.1688 - acc: 0.9318 - val_loss: 0.4925 - val_acc: 0.8168
# Epoch 18/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.1563 - acc: 0.9351 - val_loss: 0.4829 - val_acc: 0.8136
# Epoch 19/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.1471 - acc: 0.9397 - val_loss: 0.5075 - val_acc: 0.8033
# Epoch 20/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.1467 - acc: 0.9418 - val_loss: 0.5016 - val_acc: 0.8228
# Confusion matrix:
#  [[1831    5    3    0    0]
#  [   3 1477  344    0   10]
#  [   2   67 1758    0    7]
#  [   2    2    4 1740  107]
#  [   0    9   30   18 1781]]
# sensitivity 9.0
# specificity 8.0
# sensitivity 358.0
# specificity 84.0
# sensitivity 77.0
# specificity 382.0
# sensitivity 116.0
# specificity 19.0
# sensitivity 58.0
# specificity 125.0
# [{'Class': 0, 'TP': 1831, 'FN': 8.0, 'FP': 7.0, 'TN': 7354.0}, {'Class': 1, 'TP': 1477, 'FN': 357.0, 'FP': 83.0, 'TN': 7283.0}, {'Class': 2, 'TP': 1758, 'FN': 76.0, 'FP': 381.0, 'TN': 6985.0}, {'Class': 3, 'TP': 1740, 'FN': 115.0, 'FP': 18.0, 'TN': 7327.0}, {'Class': 4, 'TP': 1781, 'FN': 57.0, 'FP': 124.0, 'TN': 7238.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 48us/step
# Confusion matrix:
#  [[458   2   1   0   0]
#  [  2 325 136   0   3]
#  [  1  22 442   0   1]
#  [  1   1   0 391  52]
#  [  0   3   8   5 446]]
# sensitivity 4.0
# specificity 5.0
# sensitivity 142.0
# specificity 29.0
# sensitivity 25.0
# specificity 146.0
# sensitivity 55.0
# specificity 6.0
# sensitivity 17.0
# specificity 57.0
# [{'Class': 0, 'TP': 458, 'FN': 3.0, 'FP': 4.0, 'TN': 1835.0}, {'Class': 1, 'TP': 325, 'FN': 141.0, 'FP': 28.0, 'TN': 1806.0}, {'Class': 2, 'TP': 442, 'FN': 24.0, 'FP': 145.0, 'TN': 1689.0}, {'Class': 3, 'TP': 391, 'FN': 54.0, 'FP': 5.0, 'TN': 1850.0}, {'Class': 4, 'TP': 446, 'FN': 16.0, 'FP': 56.0, 'TN': 1782.0}]
# --- Learning curve of model training ---
# Fold  5
#
# Train Index:  (9200,)
#
# Test Index:  (2300,)
#
# --- Reshape data to be accepted by Keras ---
#
# (9200, 177, 1)
# (9200, 5)
#
# --- Fit the model ---
#
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/20
# 7360/7360 [==============================] - 1s 183us/step - loss: 0.5344 - acc: 0.8145 - val_loss: 0.3607 - val_acc: 0.8429
# Epoch 2/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.2572 - acc: 0.8978 - val_loss: 0.2487 - val_acc: 0.8973
# Epoch 3/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.1710 - acc: 0.9404 - val_loss: 0.2372 - val_acc: 0.8967
# Epoch 4/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.1412 - acc: 0.9518 - val_loss: 0.2262 - val_acc: 0.8940
# Epoch 5/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.1260 - acc: 0.9520 - val_loss: 0.1964 - val_acc: 0.9125
# Epoch 6/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.1137 - acc: 0.9571 - val_loss: 0.2353 - val_acc: 0.8946
# Epoch 7/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.1225 - acc: 0.9508 - val_loss: 0.2089 - val_acc: 0.9147
# Epoch 8/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.1025 - acc: 0.9629 - val_loss: 0.2195 - val_acc: 0.9114
# Epoch 9/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.1026 - acc: 0.9621 - val_loss: 0.3103 - val_acc: 0.8728
# Epoch 10/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.1098 - acc: 0.9557 - val_loss: 0.2178 - val_acc: 0.9087
# Epoch 11/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.0999 - acc: 0.9647 - val_loss: 0.2185 - val_acc: 0.9082
# Epoch 12/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.1081 - acc: 0.9576 - val_loss: 0.2353 - val_acc: 0.9027
# Epoch 13/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.1032 - acc: 0.9632 - val_loss: 0.2485 - val_acc: 0.8951
# Epoch 14/20
# 7360/7360 [==============================] - 1s 96us/step - loss: 0.1203 - acc: 0.9529 - val_loss: 0.2850 - val_acc: 0.8815
# Epoch 15/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.1045 - acc: 0.9614 - val_loss: 0.2550 - val_acc: 0.8886
# Epoch 16/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.0993 - acc: 0.9633 - val_loss: 0.3702 - val_acc: 0.8609
# Epoch 17/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.2596 - acc: 0.9001 - val_loss: 0.3083 - val_acc: 0.8668
# Epoch 18/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.1461 - acc: 0.9466 - val_loss: 0.2538 - val_acc: 0.8940
# Epoch 19/20
# 7360/7360 [==============================] - 1s 94us/step - loss: 0.0908 - acc: 0.9719 - val_loss: 0.2467 - val_acc: 0.8973
# Epoch 20/20
# 7360/7360 [==============================] - 1s 95us/step - loss: 0.0697 - acc: 0.9768 - val_loss: 0.2604 - val_acc: 0.8935
# Confusion matrix:
#  [[1832    3    0    0    0]
#  [   3 1817   50    0    3]
#  [   1  125 1708    0    8]
#  [   0    0    0 1832   24]
#  [   0    4    3   14 1773]]
# sensitivity 4.0
# specificity 5.0
# sensitivity 57.0
# specificity 133.0
# sensitivity 135.0
# specificity 54.0
# sensitivity 25.0
# specificity 15.0
# sensitivity 22.0
# specificity 36.0
# [{'Class': 0, 'TP': 1832, 'FN': 3.0, 'FP': 4.0, 'TN': 7361.0}, {'Class': 1, 'TP': 1817, 'FN': 56.0, 'FP': 132.0, 'TN': 7195.0}, {'Class': 2, 'TP': 1708, 'FN': 134.0, 'FP': 53.0, 'TN': 7305.0}, {'Class': 3, 'TP': 1832, 'FN': 24.0, 'FP': 14.0, 'TN': 7330.0}, {'Class': 4, 'TP': 1773, 'FN': 21.0, 'FP': 35.0, 'TN': 7371.0}]
# --- evaluate the model ---
#
# 2300/2300 [==============================] - 0s 49us/step
# Confusion matrix:
#  [[458   6   0   1   0]
#  [  6 331  81   0   9]
#  [  0 150 281   0  27]
#  [  0   2   1 398  43]
#  [  0  11   6  33 456]]
# sensitivity 8.0
# specificity 7.0
# sensitivity 97.0
# specificity 170.0
# sensitivity 178.0
# specificity 89.0
# sensitivity 47.0
# specificity 35.0
# sensitivity 51.0
# specificity 80.0
# [{'Class': 0, 'TP': 458, 'FN': 7.0, 'FP': 6.0, 'TN': 1829.0}, {'Class': 1, 'TP': 331, 'FN': 96.0, 'FP': 169.0, 'TN': 1704.0}, {'Class': 2, 'TP': 281, 'FN': 177.0, 'FP': 88.0, 'TN': 1754.0}, {'Class': 3, 'TP': 398, 'FN': 46.0, 'FP': 34.0, 'TN': 1822.0}, {'Class': 4, 'TP': 456, 'FN': 50.0, 'FP': 79.0, 'TN': 1715.0}]
# --- Learning curve of model training ---
# Avarage accuracy :%.2f% % 81.56521739130434
